# %%
#Needed Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
import matplotlib
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVR

rd = pd.read_csv("river_data.csv")
rs = pd.read_csv("river_stations.csv")
wd = pd.read_csv("weather_data.csv")
ws = pd.read_csv("weather_stations.csv")
station_no_river_dusseldorf = "6335050"
station_no_river_menden = "6335045"
station_no_river_eitorf = "6335046"


station_no_river_cologne = "6335060"
station_no_river_andernach = "6335070"
station_no_river_friedrich = "6335076"
station_no_river_cochem = "6336050"
station_no_river_kaub = "6335100"
station_no_river_lahn = "6335350"
station_no_river_marburg = "6335351"
station_no_river_mainz = "6335150"
station_no_river_grol = "6335115"
station_no_river_boos = "6335116"
station_no_river_trier = "6336500"
station_no_river_frankfurt = "6335304"#frankfurt
station_no_river_hanau = "6335310"
station_no_river_worms = "6335180"




station_no_weather_sollingen = "4741"
station_no_weather_cologne = "2968"


#saving the data size
rd_m, rd_n = rd.shape
rs_m, rs_n = rs.shape
wd_m, wd_n = wd.shape
ws_m, ws_n = ws.shape

# %% [markdown]
# # Read the River Data

# %%
rd_c = pd.read_csv('stations/station_' + station_no_river_cologne + '_river_data.csv')
rd_c.date = pd.to_datetime(rd_c.date, format='%Y-%m-%d')
rd_c = rd_c.set_index('date')
columns = ['station_no','year', 'month']
rd_c.drop(columns, inplace=True, axis=1)

rd_d = pd.read_csv('stations/station_' + station_no_river_dusseldorf + '_river_data.csv')
rd_d.date = pd.to_datetime(rd_d.date, format='%Y-%m-%d')
rd_d = rd_d.set_index('date')
columns = ['station_no','year', 'month']
rd_d.drop(columns, inplace=True, axis=1)

rd_a = pd.read_csv('stations/station_' + station_no_river_andernach + '_river_data.csv')
rd_a.date = pd.to_datetime(rd_a.date, format='%Y-%m-%d')
rd_a = rd_a.set_index('date')
columns = ['station_no','year', 'month','delta1', 'delta2', 'delta3', 'water_level' ]
rd_a.drop(columns, inplace=True, axis=1)

rd_f = pd.read_csv('stations/station_' + station_no_river_friedrich + '_river_data.csv')
rd_f.date = pd.to_datetime(rd_f.date, format='%Y-%m-%d')
rd_f = rd_f.set_index('date')
columns = ['station_no','year', 'month','delta1', 'delta2', 'delta3', 'water_level' ]
rd_f.drop(columns, inplace=True, axis=1)

rd_m = pd.read_csv('stations/station_' + station_no_river_menden + '_river_data.csv')
rd_m.date = pd.to_datetime(rd_m.date, format='%Y-%m-%d')
rd_m = rd_m.set_index('date')
columns = ['station_no','year', 'month','delta1', 'delta2', 'delta3', 'water_level' ]
#columns = ['station_no','year', 'month' ]
rd_m.drop(columns, inplace=True, axis=1)

rd_e = pd.read_csv('stations/station_' + station_no_river_menden + '_river_data.csv')
rd_e.date = pd.to_datetime(rd_e.date, format='%Y-%m-%d')
rd_e = rd_e.set_index('date')
columns = ['station_no','year', 'month','delta1', 'delta2', 'delta3', 'water_level' ]
#columns = ['station_no','year', 'month' ]
rd_e.drop(columns, inplace=True, axis=1)

rd_k = pd.read_csv('stations/station_' + station_no_river_kaub + '_river_data.csv')
rd_k.date = pd.to_datetime(rd_k.date, format='%Y-%m-%d')
rd_k = rd_k.set_index('date')
columns = ['station_no','year', 'month','delta1', 'delta2', 'delta3', 'water_level' ]
#columns = ['station_no','year', 'month' ]
rd_k.drop(columns, inplace=True, axis=1)

rd_l = pd.read_csv('stations/station_' + station_no_river_lahn + '_river_data.csv')
rd_l.date = pd.to_datetime(rd_l.date, format='%Y-%m-%d')
rd_l = rd_l.set_index('date')
columns = ['station_no','year', 'month','delta1', 'delta2', 'delta3', 'water_level' ]
#columns = ['station_no','year', 'month' ]
rd_l.drop(columns, inplace=True, axis=1)

rd_co = pd.read_csv('stations/station_' + station_no_river_cochem + '_river_data.csv')
rd_co.date = pd.to_datetime(rd_co.date, format='%Y-%m-%d')
rd_co = rd_co.set_index('date')
columns = ['station_no','year', 'month','delta1', 'delta2', 'delta3', 'water_level' ]
#columns = ['station_no','year', 'month' ]
rd_co.drop(columns, inplace=True, axis=1)

rd_mr = pd.read_csv('stations/station_' + station_no_river_marburg + '_river_data.csv')
rd_mr.date = pd.to_datetime(rd_mr.date, format='%Y-%m-%d')
rd_mr = rd_mr.set_index('date')
columns = ['station_no','year', 'month','delta1', 'delta2', 'delta3', 'water_level' ]
#columns = ['station_no','year', 'month' ]
rd_mr.drop(columns, inplace=True, axis=1)

rd_mn = pd.read_csv('stations/station_' + station_no_river_mainz + '_river_data.csv')
rd_mn.date = pd.to_datetime(rd_mn.date, format='%Y-%m-%d')
rd_mn = rd_mn.set_index('date')
columns = ['station_no','year', 'month','delta1', 'delta2', 'delta3', 'water_level' ]
#columns = ['station_no','year', 'month' ]
rd_mn.drop(columns, inplace=True, axis=1)

rd_g = pd.read_csv('stations/station_' + station_no_river_grol + '_river_data.csv')
rd_g.date = pd.to_datetime(rd_g.date, format='%Y-%m-%d')
rd_g = rd_g.set_index('date')
columns = ['station_no','year', 'month','delta1', 'delta2', 'delta3', 'water_level' ]
#columns = ['station_no','year', 'month' ]
rd_g.drop(columns, inplace=True, axis=1)

rd_b = pd.read_csv('stations/station_' + station_no_river_boos + '_river_data.csv')
rd_b.date = pd.to_datetime(rd_b.date, format='%Y-%m-%d')
rd_b = rd_b.set_index('date')
columns = ['station_no','year', 'month','delta1', 'delta2', 'delta3', 'water_level' ]
#columns = ['station_no','year', 'month' ]
rd_b.drop(columns, inplace=True, axis=1)

rd_t = pd.read_csv('stations/station_' + station_no_river_trier + '_river_data.csv')
rd_t.date = pd.to_datetime(rd_t.date, format='%Y-%m-%d')
rd_t = rd_t.set_index('date')
columns = ['station_no','year', 'month','delta1', 'delta2', 'delta3', 'water_level' ]
#columns = ['station_no','year', 'month' ]
rd_t.drop(columns, inplace=True, axis=1)

rd_f = pd.read_csv('stations/station_' + station_no_river_frankfurt + '_river_data.csv')
rd_f.date = pd.to_datetime(rd_f.date, format='%Y-%m-%d')
rd_f = rd_f.set_index('date')
columns = ['station_no','year', 'month','delta1', 'delta2', 'delta3', 'water_level' ]
#columns = ['station_no','year', 'month' ]
rd_f.drop(columns, inplace=True, axis=1)

rd_h = pd.read_csv('stations/station_' + station_no_river_hanau + '_river_data.csv')
rd_h.date = pd.to_datetime(rd_h.date, format='%Y-%m-%d')
rd_h = rd_h.set_index('date')
columns = ['station_no','year', 'month','delta1', 'delta2', 'delta3', 'water_level' ]
#columns = ['station_no','year', 'month' ]
rd_h.drop(columns, inplace=True, axis=1)

rd_w = pd.read_csv('stations/station_' + station_no_river_worms + '_river_data.csv')
rd_w.date = pd.to_datetime(rd_w.date, format='%Y-%m-%d')
rd_w = rd_w.set_index('date')
columns = ['station_no','year', 'month','delta1', 'delta2', 'delta3', 'water_level' ]
#columns = ['station_no','year', 'month' ]
rd_w.drop(columns, inplace=True, axis=1)

#rd_d.delta1.plot()

# %% [markdown]
# Checking the Correlation between water level and discharge at cologne

# %%
corrcoef_water_discharge_cologne = np.corrcoef(rd_c['water_level'], rd_c['discharge'])

# %%
rd_c[1:100000].plot(kind='scatter', x='water_level', y='discharge', color='blue')
plt.title("Rhine River Cologne Station")
plt.show()

# %% [markdown]
# # Adding the other river stations to our Train file

# %% [markdown]
# Adding to the cologne

# %%
combine_df_c = pd.merge(rd_c, rd_a, how='left', on=['date'])
combine_df_c = pd.merge(combine_df_c, rd_f, how='left', on=['date'])
combine_df_c = pd.merge(combine_df_c, rd_co, how='left', on=['date'])
combine_df_c = pd.merge(combine_df_c, rd_k, how='left', on=['date'])
combine_df_c = pd.merge(combine_df_c, rd_l, how='left', on=['date'])
combine_df_c = pd.merge(combine_df_c, rd_mr, how='left', on=['date'])
combine_df_c = pd.merge(combine_df_c, rd_mn, how='left', on=['date'])
combine_df_c = pd.merge(combine_df_c, rd_g, how='left', on=['date'])
combine_df_c = pd.merge(combine_df_c, rd_b, how='left', on=['date'])
combine_df_c = pd.merge(combine_df_c, rd_t, how='left', on=['date'])
combine_df_c = pd.merge(combine_df_c, rd_f, how='left', on=['date'])
combine_df_c = pd.merge(combine_df_c, rd_h, how='left', on=['date'])
combine_df_c = pd.merge(combine_df_c, rd_w, how='left', on=['date'])
columns = ['delta1', 'delta2', 'delta3']
rd_c.drop(columns, inplace=True, axis=1)

# %% [markdown]
# Adding to the dusseldorf

# %%
combine_df_d = pd.merge(rd_d, rd_c, how='left', on=['date'])
combine_df_d.rename(columns={'discharge_y': 'disch._cologne',}, inplace=True)
combine_df_d.rename(columns={'water_level_y': 'wat.lv_cologne',}, inplace=True)
combine_df_d = pd.merge(combine_df_d, rd_a, how='left', on=['date'])
combine_df_d.rename(columns={'discharge_x': 'disch._andernach',}, inplace=True)
combine_df_d = pd.merge(combine_df_d, rd_f, how='left', on=['date'])
combine_df_d.rename(columns={'discharge_x': 'disch._freidrich',}, inplace=True)
combine_df_d = pd.merge(combine_df_d, rd_m, how='left', on=['date'])
combine_df_d.rename(columns={'discharge_x': 'disch._menden',}, inplace=True)
combine_df_d = pd.merge(combine_df_d, rd_e, how='left', on=['date'])
combine_df_d.rename(columns={'discharge_x': 'disch._eitorf',}, inplace=True)
combine_df_d.rename(columns={'water_level_x': 'water_level',}, inplace=True)
combine_df_d = pd.merge(combine_df_d, rd_co, how='left', on=['date'])
combine_df_d = pd.merge(combine_df_d, rd_k, how='left', on=['date'])
combine_df_d = pd.merge(combine_df_d, rd_l, how='left', on=['date'])
combine_df_d = pd.merge(combine_df_d, rd_mr, how='left', on=['date'])
combine_df_d = pd.merge(combine_df_d, rd_mn, how='left', on=['date'])
combine_df_d = pd.merge(combine_df_d, rd_g, how='left', on=['date'])
combine_df_d = pd.merge(combine_df_d, rd_b, how='left', on=['date'])
combine_df_d = pd.merge(combine_df_d, rd_t, how='left', on=['date'])
combine_df_d = pd.merge(combine_df_d, rd_f, how='left', on=['date'])
combine_df_c = pd.merge(combine_df_c, rd_h, how='left', on=['date'])
combine_df_c = pd.merge(combine_df_c, rd_w, how='left', on=['date'])

# %% [markdown]
# # The features

# %% [markdown]
# You can see our features here.

# %%
combine_df_d[100:105]
#combine_df_c.to_csv(f'./combined_cologne_data.csv')
# Out:
#             disch._andernach  water_level  delta1  delta2  delta3  \
# date
# 1965-04-11            2450.0        383.0     9.0    21.0    29.0
# 1965-04-12            2390.0        375.0     8.0    17.0    29.0
# 1965-04-13            2340.0        369.0     6.0    14.0    23.0
# 1965-04-14            2380.0        374.0    -5.0     1.0     9.0
# 1965-04-15            2460.0        384.0   -10.0   -15.0    -9.0
#
#             disch._cologne  wat.lv_cologne  disch._freidrich  discharge_y  \
# date
# 1965-04-11          2410.0           380.0            2270.0        262.0
# 1965-04-12          2350.0           372.0            2200.0        250.0
# 1965-04-13          2320.0           368.0            2200.0        250.0
# 1965-04-14          2390.0           378.0            2310.0        237.0
# 1965-04-15          2410.0           380.0            2260.0        228.0
#
#             disch._eitorf  discharge_y  discharge_x  discharge_y  discharge_x  \
# date
# 1965-04-11          27.30        27.30        277.0       1920.0         18.3
# 1965-04-12          26.70        26.70        264.0       1860.0         18.6
# 1965-04-13          32.91        32.91        283.0       1860.0         23.2
# 1965-04-14          34.05        34.05        336.0       1880.0         24.3
# 1965-04-15          32.00        32.00        310.0       1840.0         22.0
#
#             discharge_y  discharge_x  discharge_y  discharge_x  discharge_y  \
# date
# 1965-04-11         8.80       1850.0        21.57         21.3        202.0
# 1965-04-12         9.26       1840.0        24.87         20.3        204.0
# 1965-04-13        10.80       1840.0        24.45         21.3        244.0
# 1965-04-14        10.80       1860.0        27.59         22.8        240.0
# 1965-04-15        10.00       1810.0        23.68         19.9        266.0
#
#             discharge
# date
# 1965-04-11      262.0
# 1965-04-12      250.0
# 1965-04-13      250.0
# 1965-04-14      237.0
# 1965-04-15      228.0

# %% [markdown]
# # Training the model (Functions)

# %%
def define_X_y(df, pred_start, prev_X, prev_y):
    head_df = df[df.index < pred_start]

    
    y_last = head_df['water_level'][-1]
    X = head_df
    y1 = head_df.water_level.shift(-1)
    y2 = head_df.water_level.shift(-2)
    y3 = head_df.water_level.shift(-3)
    X = np.nan_to_num(X, nan=0)
    X_normalized = X
    x_last = X_normalized[-1,:]
    x_last = x_last.reshape((1, np.shape(x_last)[0]))
    X_normalized = X_normalized[3:-3]
    y1 = y1[3:-3]
    y2 = y2[3:-3]
    y3 = y3[3:-3]
    if prev_X.shape[0] > 3:
        X_normalized = np.concatenate((prev_X, X_normalized))
        y1 = np.concatenate((prev_y[:,0], y1))
        y2 = np.concatenate((prev_y[:,1], y2))
        y3 = np.concatenate((prev_y[:,2], y3))
    return X_normalized, x_last, y_last, y1, y2, y3

# %%
def train_the_model(X, x_last, y_last, y1, y2, y3):
    X_train, X_test, y_train1, y_test1 = train_test_split(X, y1, test_size=0.05, random_state=0)
    regressor1 = LinearRegression()  
    regressor1.fit(X_train, y_train1) #training the algorithm

    y_pred1 = regressor1.predict(X_test)
    y_pred1 = np.diff(y_pred1)
    y_test1 = np.diff(y_test1)
    y_real1 = regressor1.predict(x_last)
    y_real1 = y_real1 - y_last
    
    X_train, X_test, y_train2, y_test2 = train_test_split(X, y2, test_size=0.05, random_state=5)
    regressor2 = LinearRegression()  
    regressor2.fit(X_train, y_train2) #training the algorithm

    y_pred2 = regressor2.predict(X_test)
    y_pred2 = np.diff(y_pred2)
    y_test2 = np.diff(y_test2)
    y_real2 = regressor2.predict(x_last)
    y_real2 = y_real2 - y_last

    X_train, X_test, y_train3, y_test3 = train_test_split(X, y3, test_size=0.05, random_state=2)
    regressor3 = LinearRegression()  
    regressor3.fit(X_train, y_train3) #training the algorithm

    y_pred3 = regressor3.predict(X_test)
    y_pred3 = np.diff(y_pred3)
    y_test3 = np.diff(y_test3)
    y_real3 = regressor3.predict(x_last)
    y_real3 = y_real3 - y_last
    
    y_true = np.concatenate((y_test1, y_test2, y_test3), axis=None)
    y_pred = np.concatenate((y_pred1, y_pred2, y_pred3), axis=None)
    y_real = np.concatenate((y_real1, y_real2, y_real3), axis=None)
    y_real = y_real.reshape((np.shape(y_real)[0],1))

    return y_true, y_pred, y_real

# %% [markdown]
# # Training for Cologne

# %%
skip_missing_days = 16
full_range = pd.date_range(combine_df_c.index.min(), combine_df_c.index.max()+pd.Timedelta(days=1)) #TODO add last day!
combine_df_c = combine_df_c.reindex(full_range, fill_value=np.NaN)

next_gap = pd.to_datetime(combine_df_c.water_level.isnull().idxmax())
tail_gap = next_gap + pd.Timedelta(days=skip_missing_days)
prev_X = pd.DataFrame(np.zeros([1, 9])*0)
prev_y = pd.DataFrame(np.zeros([1, 3])*0)
r2_results = np.zeros(1)
X_real_test_c = np.zeros([1,np.shape(combine_df_c)[1]])
i=0
y_real_test_c = np.zeros([1,1])

# %%
while next_gap:
    X, x_last, y_last, y1, y2, y3 = define_X_y(combine_df_c, next_gap, prev_X, prev_y)
    X_real_test_c = np.vstack((X_real_test_c, x_last))
    X = np.nan_to_num(X, nan=0)
    indexNames = combine_df_c[ combine_df_c.index < tail_gap ].index
    combine_df_c.drop(indexNames , inplace=True)
    y1 = np.nan_to_num(y1, nan=0)
    y2 = np.nan_to_num(y2, nan=0)
    y3 = np.nan_to_num(y3, nan=0)
    y_true, y_pred, y_real = train_the_model(X, x_last, y_last, y1,y2,y3)
    y_real_test_c = np.vstack((y_real_test_c, y_real))

    if np.shape(combine_df_c)[0] < 2:
        break
    next_gap = pd.to_datetime(combine_df_c.water_level.isnull().idxmax())
    tail_gap = next_gap + pd.Timedelta(days=skip_missing_days)
    prev_X = X
    prev_y = [y1, y2, y3]
    prev_y = np.transpose(prev_y)
    i += 1
    percentage = (100*i)/165
    print("Competed_percentage: %" + str(int(percentage)))
# Out:
# Competed_percentage: %0
# Competed_percentage: %1
# Competed_percentage: %1
# Competed_percentage: %2
# Competed_percentage: %3
# Competed_percentage: %3
# Competed_percentage: %4
# Competed_percentage: %4
# Competed_percentage: %5
# Competed_percentage: %6
# Competed_percentage: %6
# Competed_percentage: %7
# Competed_percentage: %7
# Competed_percentage: %8
# Competed_percentage: %9
# Competed_percentage: %9
# Competed_percentage: %10
# Competed_percentage: %10
# Competed_percentage: %11
# Competed_percentage: %12
# Competed_percentage: %12
# Competed_percentage: %13
# Competed_percentage: %13
# Competed_percentage: %14
# Competed_percentage: %15
# Competed_percentage: %15
# Competed_percentage: %16
# Competed_percentage: %16
# Competed_percentage: %17
# Competed_percentage: %18
# Competed_percentage: %18
# Competed_percentage: %19
# Competed_percentage: %20
# Competed_percentage: %20
# Competed_percentage: %21
# Competed_percentage: %21
# Competed_percentage: %22
# Competed_percentage: %23
# Competed_percentage: %23
# Competed_percentage: %24
# Competed_percentage: %24
# Competed_percentage: %25
# Competed_percentage: %26
# Competed_percentage: %26
# Competed_percentage: %27
# Competed_percentage: %27
# Competed_percentage: %28
# Competed_percentage: %29
# Competed_percentage: %29
# Competed_percentage: %30
# Competed_percentage: %30
# Competed_percentage: %31
# Competed_percentage: %32
# Competed_percentage: %32
# Competed_percentage: %33
# Competed_percentage: %33
# Competed_percentage: %34
# Competed_percentage: %35
# Competed_percentage: %35
# Competed_percentage: %36
# Competed_percentage: %36
# Competed_percentage: %37
# Competed_percentage: %38
# Competed_percentage: %38
# Competed_percentage: %39
# Competed_percentage: %40
# Competed_percentage: %40
# Competed_percentage: %41
# Competed_percentage: %41
# Competed_percentage: %42
# Competed_percentage: %43
# Competed_percentage: %43
# Competed_percentage: %44
# Competed_percentage: %44
# Competed_percentage: %45
# Competed_percentage: %46
# Competed_percentage: %46
# Competed_percentage: %47
# Competed_percentage: %47
# Competed_percentage: %48
# Competed_percentage: %49
# Competed_percentage: %49
# Competed_percentage: %50
# Competed_percentage: %50
# Competed_percentage: %51
# Competed_percentage: %52
# Competed_percentage: %52
# Competed_percentage: %53
# Competed_percentage: %53
# Competed_percentage: %54
# Competed_percentage: %55
# Competed_percentage: %55
# Competed_percentage: %56
# Competed_percentage: %56
# Competed_percentage: %57
# Competed_percentage: %58
# Competed_percentage: %58
# Competed_percentage: %59
# Competed_percentage: %60
# Competed_percentage: %60
# Competed_percentage: %61
# Competed_percentage: %61
# Competed_percentage: %62
# Competed_percentage: %63
# Competed_percentage: %63
# Competed_percentage: %64
# Competed_percentage: %64
# Competed_percentage: %65
# Competed_percentage: %66
# Competed_percentage: %66
# Competed_percentage: %67
# Competed_percentage: %67
# Competed_percentage: %68
# Competed_percentage: %69
# Competed_percentage: %69
# Competed_percentage: %70
# Competed_percentage: %70
# Competed_percentage: %71
# Competed_percentage: %72
# Competed_percentage: %72
# Competed_percentage: %73
# Competed_percentage: %73
# Competed_percentage: %74
# Competed_percentage: %75
# Competed_percentage: %75
# Competed_percentage: %76
# Competed_percentage: %76
# Competed_percentage: %77
# Competed_percentage: %78
# Competed_percentage: %78
# Competed_percentage: %79
# Competed_percentage: %80
# Competed_percentage: %80
# Competed_percentage: %81
# Competed_percentage: %81
# Competed_percentage: %82
# Competed_percentage: %83
# Competed_percentage: %83
# Competed_percentage: %84
# Competed_percentage: %84
# Competed_percentage: %85
# Competed_percentage: %86
# Competed_percentage: %86
# Competed_percentage: %87
# Competed_percentage: %87
# Competed_percentage: %88
# Competed_percentage: %89
# Competed_percentage: %89
# Competed_percentage: %90
# Competed_percentage: %90
# Competed_percentage: %91
# Competed_percentage: %92
# Competed_percentage: %92
# Competed_percentage: %93
# Competed_percentage: %93
# Competed_percentage: %94
# Competed_percentage: %95
# Competed_percentage: %95
# Competed_percentage: %96
# Competed_percentage: %96
# Competed_percentage: %97
# Competed_percentage: %98
# Competed_percentage: %98
# Competed_percentage: %99
# Competed_percentage: %100

# %%
X_real_test_c = X_real_test_c[1:-1,:]
y_real_test_c = y_real_test_c[1:-3,:]
y_true_c = y_true
y_pred_c = y_pred
print("Cologne R2 score: " + str(r2_score(y_true_c, y_pred_c)))
# Out:
# Cologne R2 score: 0.945286241556861

# %% [markdown]
# # Training Dusseldorf

# %%
skip_missing_days = 16
full_range = pd.date_range(combine_df_d.index.min(), combine_df_d.index.max()+pd.Timedelta(days=1)) #TODO add last day!
combine_df_d = combine_df_d.reindex(full_range, fill_value=np.NaN)

next_gap = pd.to_datetime(combine_df_d.water_level.isnull().idxmax())
tail_gap = next_gap + pd.Timedelta(days=skip_missing_days)
prev_X = pd.DataFrame(np.zeros([1, 9])*0)
prev_y = pd.DataFrame(np.zeros([1, 3])*0)
r2_results = np.zeros(1)
X_real_test_d = np.zeros([1,np.shape(combine_df_d)[1]])
i=0
y_real_test_d = np.zeros([1,1])
#y_real_test_svm_d = np.zeros([1,1])

# %%
while next_gap:
    X, x_last, y_last, y1, y2, y3 = define_X_y(combine_df_d, next_gap, prev_X, prev_y)
    X_real_test_d = np.vstack((X_real_test_d, x_last))
    X = np.nan_to_num(X, nan=0)
    indexNames = combine_df_d[ combine_df_d.index < tail_gap ].index
    combine_df_d.drop(indexNames , inplace=True)
    y1 = np.nan_to_num(y1, nan=0)
    y2 = np.nan_to_num(y2, nan=0)
    y3 = np.nan_to_num(y3, nan=0)
    y_true, y_pred, y_real= train_the_model(X,x_last, y_last, y1,y2,y3)
    y_real_test_d = np.vstack((y_real_test_d, y_real))
    if np.shape(combine_df_d)[0] < 2:
        break
    next_gap = pd.to_datetime(combine_df_d.water_level.isnull().idxmax())
    tail_gap = next_gap + pd.Timedelta(days=skip_missing_days)
    prev_X = X
    prev_y = [y1, y2, y3]
    prev_y = np.transpose(prev_y)
    i += 1
    percentage = (100*i)/165
    print("Competed_percentage: %" + str(int(percentage)))
# Out:
# Competed_percentage: %0
# Competed_percentage: %1
# Competed_percentage: %1
# Competed_percentage: %2
# Competed_percentage: %3
# Competed_percentage: %3
# Competed_percentage: %4
# Competed_percentage: %4
# Competed_percentage: %5
# Competed_percentage: %6
# Competed_percentage: %6
# Competed_percentage: %7
# Competed_percentage: %7
# Competed_percentage: %8
# Competed_percentage: %9
# Competed_percentage: %9
# Competed_percentage: %10
# Competed_percentage: %10
# Competed_percentage: %11
# Competed_percentage: %12
# Competed_percentage: %12
# Competed_percentage: %13
# Competed_percentage: %13
# Competed_percentage: %14
# Competed_percentage: %15
# Competed_percentage: %15
# Competed_percentage: %16
# Competed_percentage: %16
# Competed_percentage: %17
# Competed_percentage: %18
# Competed_percentage: %18
# Competed_percentage: %19
# Competed_percentage: %20
# Competed_percentage: %20
# Competed_percentage: %21
# Competed_percentage: %21
# Competed_percentage: %22
# Competed_percentage: %23
# Competed_percentage: %23
# Competed_percentage: %24
# Competed_percentage: %24
# Competed_percentage: %25
# Competed_percentage: %26
# Competed_percentage: %26
# Competed_percentage: %27
# Competed_percentage: %27
# Competed_percentage: %28
# Competed_percentage: %29
# Competed_percentage: %29
# Competed_percentage: %30
# Competed_percentage: %30
# Competed_percentage: %31
# Competed_percentage: %32
# Competed_percentage: %32
# Competed_percentage: %33
# Competed_percentage: %33
# Competed_percentage: %34
# Competed_percentage: %35
# Competed_percentage: %35
# Competed_percentage: %36
# Competed_percentage: %36
# Competed_percentage: %37
# Competed_percentage: %38
# Competed_percentage: %38
# Competed_percentage: %39
# Competed_percentage: %40
# Competed_percentage: %40
# Competed_percentage: %41
# Competed_percentage: %41
# Competed_percentage: %42
# Competed_percentage: %43
# Competed_percentage: %43
# Competed_percentage: %44
# Competed_percentage: %44
# Competed_percentage: %45
# Competed_percentage: %46
# Competed_percentage: %46
# Competed_percentage: %47
# Competed_percentage: %47
# Competed_percentage: %48
# Competed_percentage: %49
# Competed_percentage: %49
# Competed_percentage: %50
# Competed_percentage: %50
# Competed_percentage: %51
# Competed_percentage: %52
# Competed_percentage: %52
# Competed_percentage: %53
# Competed_percentage: %53
# Competed_percentage: %54
# Competed_percentage: %55
# Competed_percentage: %55
# Competed_percentage: %56
# Competed_percentage: %56
# Competed_percentage: %57
# Competed_percentage: %58
# Competed_percentage: %58
# Competed_percentage: %59
# Competed_percentage: %60
# Competed_percentage: %60
# Competed_percentage: %61
# Competed_percentage: %61
# Competed_percentage: %62
# Competed_percentage: %63
# Competed_percentage: %63
# Competed_percentage: %64
# Competed_percentage: %64
# Competed_percentage: %65
# Competed_percentage: %66
# Competed_percentage: %66
# Competed_percentage: %67
# Competed_percentage: %67
# Competed_percentage: %68
# Competed_percentage: %69
# Competed_percentage: %69
# Competed_percentage: %70
# Competed_percentage: %70
# Competed_percentage: %71
# Competed_percentage: %72
# Competed_percentage: %72
# Competed_percentage: %73
# Competed_percentage: %73
# Competed_percentage: %74
# Competed_percentage: %75
# Competed_percentage: %75
# Competed_percentage: %76
# Competed_percentage: %76
# Competed_percentage: %77
# Competed_percentage: %78
# Competed_percentage: %78
# Competed_percentage: %79
# Competed_percentage: %80
# Competed_percentage: %80
# Competed_percentage: %81
# Competed_percentage: %81
# Competed_percentage: %82
# Competed_percentage: %83
# Competed_percentage: %83
# Competed_percentage: %84
# Competed_percentage: %84
# Competed_percentage: %85
# Competed_percentage: %86
# Competed_percentage: %86
# Competed_percentage: %87
# Competed_percentage: %87
# Competed_percentage: %88
# Competed_percentage: %89
# Competed_percentage: %89
# Competed_percentage: %90
# Competed_percentage: %90
# Competed_percentage: %91
# Competed_percentage: %92
# Competed_percentage: %92
# Competed_percentage: %93
# Competed_percentage: %93
# Competed_percentage: %94
# Competed_percentage: %95
# Competed_percentage: %95
# Competed_percentage: %96
# Competed_percentage: %96
# Competed_percentage: %97
# Competed_percentage: %98
# Competed_percentage: %98
# Competed_percentage: %99
# Competed_percentage: %100

# %%
X_real_test_d = X_real_test_d[1:-1,:]
y_real_test_d = y_real_test_d[1:-3,:]
y_true_d = y_true
y_pred_d = y_pred
print("Dusseldorf R2 score: " + str(r2_score(y_true_d, y_pred_d)))
# Out:
# Dusseldorf R2 score: 0.9602864150460295

# %% [markdown]
# # Exportingthe results

# %%
y_real_test = np.vstack((y_real_test_d, y_real_test_c))
predict_df = pd.read_csv('./to_predict.csv', index_col=False)
predict_df['delta'] = y_real_test

# %%
predict_df.to_csv('./team9submission.csv', index=False)

# %% [markdown]
# # Calculating R2 Score

# %%
y_true_combined = np.concatenate((y_true_d, y_true_c), axis=0)
y_pred_combined = np.concatenate((y_pred_d, y_pred_c), axis=0)
print("general R2 score:" + str(r2_score(y_true_combined, y_pred_combined)))
# Out:
# general R2 score:0.9529345627372428
